# %% [markdown]
# # Welcome to Colab!

# %%
Message = 'Hello World'
print(Message.count('Hello'))
print(Message.count('l'))
# Out:
# 1
# 3

# %% [markdown]
# Code for conactination of the string

# %%
FirstName = 'Shivanshu'
LastName = 'Gupta'
Message = FirstName + LastName
print(Message)
# Out:
# ShivanshuGupta

# %%
M1 = int (input ("Enter the first number: "))
M2 = int (input ("Enter the second number: "))
M3 = int (input ("Enter the third number: "))
M4 = int (input ("Enter the fourth number: "))
M5 = int (input ("Enter the fifth number: "))
TotalMarks = M1+M2+M3+M4+M5/5
Avg = TotalMarks/5
Percentage=(TotalMarks/500)*100
print(Percentage)
print(TotalMarks)
if Avg>=90:
  print("Grade A")
elif Avg>=80:
  print("Grade B")
elif Avg>=70:
  print("Grade C")
elif Avg>=60:
  print("Grade D")
# Out:
# Enter the first number: 45
# Enter the second number: 76
# Enter the third number: 87
# Enter the fourth number: 98
# Enter the fifth number: 78
# 64.32
# 321.6
# Grade D
